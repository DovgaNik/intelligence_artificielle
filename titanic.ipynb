# %%
import scipy as sc
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the data

# %%
dataset = pd.read_csv("Titanic-Dataset.csv")
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # Fill in the missing values

# %% [markdown]
# ## Embarked
# Due to the fact that most of the values of the embarked column are equal to S it is safe to fill the other 2 missing values with S. Additionally, based on the price we may assume that the passengers are coming from England.

# %%
dataset["Embarked"] = dataset["Embarked"].fillna('S')
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Age

# %%
dataset = dataset.dropna(subset=['Age'])
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [714 rows x 12 columns]

# %% [markdown]
# # Cabin

# %%
dataset = dataset.drop('Cabin', axis=1)
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 885      5            382652  29.1250        Q
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [714 rows x 11 columns]

# %% [markdown]
# # One-Hot encoding

# %%
dataset = pd.get_dummies(dataset, columns=['Pclass', 'Embarked', 'Sex'])
dataset
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 885          886         0               Rice, Mrs. William (Margaret Norton)
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare  Pclass_1  Pclass_2  \
# 0    22.0      1      0         A/5 21171   7.2500     False     False
# 1    38.0      1      0          PC 17599  71.2833      True     False
# 2    26.0      0      0  STON/O2. 3101282   7.9250     False     False
# 3    35.0      1      0            113803  53.1000      True     False
# 4    35.0      0      0            373450   8.0500     False     False
# ..    ...    ...    ...               ...      ...       ...       ...
# 885  39.0      0      5            382652  29.1250     False     False
# 886  27.0      0      0            211536  13.0000     False      True
# 887  19.0      0      0            112053  30.0000      True     False
# 889  26.0      0      0            111369  30.0000      True     False
# 890  32.0      0      0            370376   7.7500     False     False
#
#      Pclass_3  Embarked_C  Embarked_Q  Embarked_S  Sex_female  Sex_male
# 0        True       False       False        True       False      True
# 1       False        True       False       False        True     False
# 2        True       False       False        True        True     False
# 3       False       False       False        True        True     False
# 4        True       False       False        True       False      True
# ..        ...         ...         ...         ...         ...       ...
# 885      True       False        True       False        True     False
# 886     False       False       False        True       False      True
# 887     False       False       False        True        True     False
# 889     False        True       False       False       False      True
# 890      True       False        True       False       False      True
#
# [714 rows x 16 columns]

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Family size

# %%
dataset["FamilySize"] = dataset.apply(lambda row: row['SibSp'] + row['Parch'] + 1, axis=1)
dataset
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 885          886         0               Rice, Mrs. William (Margaret Norton)
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare  Pclass_1  Pclass_2  \
# 0    22.0      1      0         A/5 21171   7.2500     False     False
# 1    38.0      1      0          PC 17599  71.2833      True     False
# 2    26.0      0      0  STON/O2. 3101282   7.9250     False     False
# 3    35.0      1      0            113803  53.1000      True     False
# 4    35.0      0      0            373450   8.0500     False     False
# ..    ...    ...    ...               ...      ...       ...       ...
# 885  39.0      0      5            382652  29.1250     False     False
# 886  27.0      0      0            211536  13.0000     False      True
# 887  19.0      0      0            112053  30.0000      True     False
# 889  26.0      0      0            111369  30.0000      True     False
# 890  32.0      0      0            370376   7.7500     False     False
#
#      Pclass_3  Embarked_C  Embarked_Q  Embarked_S  Sex_female  Sex_male  \
# 0        True       False       False        True       False      True
# 1       False        True       False       False        True     False
# 2        True       False       False        True        True     False
# 3       False       False       False        True        True     False
# 4        True       False       False        True       False      True
# ..        ...         ...         ...         ...         ...       ...
# 885      True       False        True       False        True     False
# 886     False       False       False        True       False      True
# 887     False       False       False        True        True     False
# 889     False        True       False       False       False      True
# 890      True       False        True       False       False      True
#
#      FamilySize
# 0             2
# 1             2
# 2             1
# 3             2
# 4             1
# ..          ...
# 885           6
# 886           1
# 887           1
# 889           1
# 890           1
#
# [714 rows x 17 columns]

# %% [markdown]
# ### Is single ?

# %%
dataset["isSingle"] = dataset.apply(lambda row: row['FamilySize'] == 1, axis=1)
dataset
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 885          886         0               Rice, Mrs. William (Margaret Norton)
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare  Pclass_1  Pclass_2  \
# 0    22.0      1      0         A/5 21171   7.2500     False     False
# 1    38.0      1      0          PC 17599  71.2833      True     False
# 2    26.0      0      0  STON/O2. 3101282   7.9250     False     False
# 3    35.0      1      0            113803  53.1000      True     False
# 4    35.0      0      0            373450   8.0500     False     False
# ..    ...    ...    ...               ...      ...       ...       ...
# 885  39.0      0      5            382652  29.1250     False     False
# 886  27.0      0      0            211536  13.0000     False      True
# 887  19.0      0      0            112053  30.0000      True     False
# 889  26.0      0      0            111369  30.0000      True     False
# 890  32.0      0      0            370376   7.7500     False     False
#
#      Pclass_3  Embarked_C  Embarked_Q  Embarked_S  Sex_female  Sex_male  \
# 0        True       False       False        True       False      True
# 1       False        True       False       False        True     False
# 2        True       False       False        True        True     False
# 3       False       False       False        True        True     False
# 4        True       False       False        True       False      True
# ..        ...         ...         ...         ...         ...       ...
# 885      True       False        True       False        True     False
# 886     False       False       False        True       False      True
# 887     False       False       False        True        True     False
# 889     False        True       False       False       False      True
# 890      True       False        True       False       False      True
#
#      FamilySize  isSingle
# 0             2     False
# 1             2     False
# 2             1      True
# 3             2     False
# 4             1      True
# ..          ...       ...
# 885           6     False
# 886           1      True
# 887           1      True
# 889           1      True
# 890           1      True
#
# [714 rows x 18 columns]

# %% [markdown]
# ## Title extraction

# %%
dataset["officialTitle"] = dataset.apply(lambda row: row['Name'].split(', ')[1].split(' ')[0], axis=1)
dataset
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 885          886         0               Rice, Mrs. William (Margaret Norton)
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare  Pclass_1  Pclass_2  \
# 0    22.0      1      0         A/5 21171   7.2500     False     False
# 1    38.0      1      0          PC 17599  71.2833      True     False
# 2    26.0      0      0  STON/O2. 3101282   7.9250     False     False
# 3    35.0      1      0            113803  53.1000      True     False
# 4    35.0      0      0            373450   8.0500     False     False
# ..    ...    ...    ...               ...      ...       ...       ...
# 885  39.0      0      5            382652  29.1250     False     False
# 886  27.0      0      0            211536  13.0000     False      True
# 887  19.0      0      0            112053  30.0000      True     False
# 889  26.0      0      0            111369  30.0000      True     False
# 890  32.0      0      0            370376   7.7500     False     False
#
#      Pclass_3  Embarked_C  Embarked_Q  Embarked_S  Sex_female  Sex_male  \
# 0        True       False       False        True       False      True
# 1       False        True       False       False        True     False
# 2        True       False       False        True        True     False
# 3       False       False       False        True        True     False
# 4        True       False       False        True       False      True
# ..        ...         ...         ...         ...         ...       ...
# 885      True       False        True       False        True     False
# 886     False       False       False        True       False      True
# 887     False       False       False        True        True     False
# 889     False        True       False       False       False      True
# 890      True       False        True       False       False      True
#
#      FamilySize  isSingle officialTitle
# 0             2     False           Mr.
# 1             2     False          Mrs.
# 2             1      True         Miss.
# 3             2     False          Mrs.
# 4             1      True           Mr.
# ..          ...       ...           ...
# 885           6     False          Mrs.
# 886           1      True          Rev.
# 887           1      True         Miss.
# 889           1      True           Mr.
# 890           1      True           Mr.
#
# [714 rows x 19 columns]

# %% [markdown]
# ## Age groups
#
# Considering the ages by the standarts of 1910s
# * Child 0-21
# * Adult 22-60
# * Senior 71+

# %%
dataset["ageGroup"] = dataset.apply(lambda row:
    "Child" if row["Age"] < 22 else
    "Adult" if 21 < row["Age"] < 61 else
    "Senior"
, axis=1)

dataset = pd.get_dummies(dataset, columns=['ageGroup'])
dataset
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 885          886         0               Rice, Mrs. William (Margaret Norton)
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare  Pclass_1  Pclass_2  ...  \
# 0    22.0      1      0         A/5 21171   7.2500     False     False  ...
# 1    38.0      1      0          PC 17599  71.2833      True     False  ...
# 2    26.0      0      0  STON/O2. 3101282   7.9250     False     False  ...
# 3    35.0      1      0            113803  53.1000      True     False  ...
# 4    35.0      0      0            373450   8.0500     False     False  ...
# ..    ...    ...    ...               ...      ...       ...       ...  ...
# 885  39.0      0      5            382652  29.1250     False     False  ...
# 886  27.0      0      0            211536  13.0000     False      True  ...
# 887  19.0      0      0            112053  30.0000      True     False  ...
# 889  26.0      0      0            111369  30.0000      True     False  ...
# 890  32.0      0      0            370376   7.7500     False     False  ...
#
#      Embarked_Q  Embarked_S  Sex_female  Sex_male  FamilySize  isSingle  \
# 0         False        True       False      True           2     False
# 1         False       False        True     False           2     False
# 2         False        True        True     False           1      True
# 3         False        True        True     False           2     False
# 4         False        True       False      True           1      True
# ..          ...         ...         ...       ...         ...       ...
# 885        True       False        True     False           6     False
# 886       False        True       False      True           1      True
# 887       False        True        True     False           1      True
# 889       False       False       False      True           1      True
# 890        True       False       False      True           1      True
#
#      officialTitle  ageGroup_Adult ageGroup_Child  ageGroup_Senior
# 0              Mr.            True          False            False
# 1             Mrs.            True          False            False
# 2            Miss.            True          False            False
# 3             Mrs.            True          False            False
# 4              Mr.            True          False            False
# ..             ...             ...            ...              ...
# 885           Mrs.            True          False            False
# 886           Rev.            True          False            False
# 887          Miss.           False           True            False
# 889            Mr.            True          False            False
# 890            Mr.            True          False            False
#
# [714 rows x 22 columns]

# %% [markdown]
# ## Fare bins
# * Cheap < 17.5
# * Medium < 52.5
# * Expensive > 52.5

# %%
dataset["fareBin"] = dataset.apply(lambda row:
    "Cheap" if row["Fare"] < 17.5 else
    "Medium" if 21 < row["Fare"] < 52.5 else
    "Expensive"
, axis=1)

dataset = pd.get_dummies(dataset, columns=['fareBin'])
dataset
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 885          886         0               Rice, Mrs. William (Margaret Norton)
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
#       Age  SibSp  Parch            Ticket     Fare  Pclass_1  Pclass_2  ...  \
# 0    22.0      1      0         A/5 21171   7.2500     False     False  ...
# 1    38.0      1      0          PC 17599  71.2833      True     False  ...
# 2    26.0      0      0  STON/O2. 3101282   7.9250     False     False  ...
# 3    35.0      1      0            113803  53.1000      True     False  ...
# 4    35.0      0      0            373450   8.0500     False     False  ...
# ..    ...    ...    ...               ...      ...       ...       ...  ...
# 885  39.0      0      5            382652  29.1250     False     False  ...
# 886  27.0      0      0            211536  13.0000     False      True  ...
# 887  19.0      0      0            112053  30.0000      True     False  ...
# 889  26.0      0      0            111369  30.0000      True     False  ...
# 890  32.0      0      0            370376   7.7500     False     False  ...
#
#      Sex_male  FamilySize  isSingle  officialTitle  ageGroup_Adult  \
# 0        True           2     False            Mr.            True
# 1       False           2     False           Mrs.            True
# 2       False           1      True          Miss.            True
# 3       False           2     False           Mrs.            True
# 4        True           1      True            Mr.            True
# ..        ...         ...       ...            ...             ...
# 885     False           6     False           Mrs.            True
# 886      True           1      True           Rev.            True
# 887     False           1      True          Miss.           False
# 889      True           1      True            Mr.            True
# 890      True           1      True            Mr.            True
#
#      ageGroup_Child  ageGroup_Senior  fareBin_Cheap fareBin_Expensive  \
# 0             False            False           True             False
# 1             False            False          False              True
# 2             False            False           True             False
# 3             False            False          False              True
# 4             False            False           True             False
# ..              ...              ...            ...               ...
# 885           False            False          False             False
# 886           False            False           True             False
# 887            True            False          False             False
# 889           False            False          False             False
# 890           False            False           True             False
#
#      fareBin_Medium
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ..              ...
# 885            True
# 886           False
# 887            True
# 889            True
# 890           False
#
# [714 rows x 25 columns]
